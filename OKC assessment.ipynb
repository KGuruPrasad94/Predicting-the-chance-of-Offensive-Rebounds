# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PPD = pd.read_csv("player_pos_data.csv")
PPD.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
PPD.set_index("Id", inplace = True)
PPD.head()
# Out:
#     player_id  position  position2
# Id
# 1           1       1.0        NaN
# 2           2       2.0        1.0
# 3           3       1.0        NaN
# 4           4       2.0        1.0
# 5           5       5.0        NaN

# %%
PPD.shape
# Out:
# (1376, 3)

# %%
PPD.isnull().sum()
# Out:
# player_id      0
# position       2
# position2    874
# dtype: int64

# %%
PRD = pd.read_csv("player_reb_data.csv")
PRD.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
PRD.set_index("Id", inplace = True)
PRD.head()
# Out:
#     player_id  games      minutes  off_rebs  def_rebs  off_rebchances  \
# Id
# 1          39     50   856.516667        33       222             744
# 2         166     54  1680.123333        39       210            1638
# 3         317     70  1962.798333       148       474            1706
# 4         251    214  3987.693333        95       441            3715
# 5          10    187  4956.941667        85       978            4581
#
#     def_rebchances
# Id
# 1              759
# 2             1461
# 3             1805
# 4             3584
# 5             4379

# %%
PRD.shape
# Out:
# (1007, 7)

# %%
PRD.isnull().sum()
# Out:
# player_id         0
# games             0
# minutes           0
# off_rebs          0
# def_rebs          0
# off_rebchances    0
# def_rebchances    0
# dtype: int64

# %%
loc_test = pd.read_csv("testing_data_loc.csv")
loc_test.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
loc_test.set_index("Id", inplace = True)
loc_test.head()
# Out:
#     game_id  playbyplayorder_id row_type  AtShot_loc_x_off_player_1  \
# Id
# 1         4                 595     shot                 -19.027053
# 2         4                 596     shot                 -31.241325
# 3         4                 597     shot                 -19.010274
# 4         4                 598     shot                 -33.708835
# 5         4                 599     shot                 -14.256493
#
#     AtShot_loc_y_off_player_1  AtRim_loc_x_off_player_1  \
# Id
# 1                   19.871164                -19.561299
# 2                  -16.557071                -28.321632
# 3                  -13.595167                -12.321997
# 4                  -13.357808                -29.629455
# 5                    5.269441                -13.189371
#
#     AtRim_loc_y_off_player_1  AtShot_loc_x_off_player_2  \
# Id
# 1                  18.261468                 -28.772848
# 2                 -15.065638                 -16.253902
# 3                  -9.573885                 -33.948531
# 4                 -16.061489                 -40.948591
# 5                   2.904353                 -46.556349
#
#     AtShot_loc_y_off_player_2  AtRim_loc_x_off_player_2  ...  \
# Id                                                       ...
# 1                  -20.131305                -25.062257  ...
# 2                   -0.423465                -12.688562  ...
# 3                   12.760393                -26.410282  ...
# 4                   22.274634                -35.058592  ...
# 5                    4.344373                -42.790092  ...
#
#     AtRim_loc_x_def_player_3  AtRim_loc_y_def_player_3  \
# Id
# 1                 -37.198845                -17.366327
# 2                 -38.935461                 -3.489779
# 3                 -30.802708                  6.006223
# 4                 -34.623914                 -1.302901
# 5                 -44.305512                 -1.282830
#
#     AtShot_loc_x_def_player_4  AtShot_loc_y_def_player_4  \
# Id
# 1                  -40.893383                   5.999704
# 2                  -35.476110                  -7.463574
# 3                  -25.341379                  -1.232503
# 4                  -35.477993                  -6.979465
# 5                  -37.705134                  -9.482981
#
#     AtRim_loc_x_def_player_4  AtRim_loc_y_def_player_4  \
# Id
# 1                 -40.185606                  3.857986
# 2                 -36.617299                 -5.663391
# 3                 -28.746937                 -1.924971
# 4                 -36.038071                 -9.675009
# 5                 -39.735703                 -5.733037
#
#     AtShot_loc_x_def_player_5  AtShot_loc_y_def_player_5  \
# Id
# 1                  -41.937047                   0.940924
# 2                  -25.744579                   2.007568
# 3                  -37.276387                   4.779776
# 4                  -27.585973                  11.054745
# 5                  -39.595369                   5.797657
#
#     AtRim_loc_x_def_player_5  AtRim_loc_y_def_player_5
# Id
# 1                 -41.128611                 -0.126855
# 2                 -26.997568                  0.148252
# 3                 -41.756499                  5.591011
# 4                 -29.002834                  9.131641
# 5                 -34.375548                  6.279269
#
# [5 rows x 43 columns]

# %%
loc_test.shape
# Out:
# (390550, 43)

# %%
loc_test.isnull().sum()
# Out:
# game_id                          0
# playbyplayorder_id               0
# row_type                         0
# AtShot_loc_x_off_player_1    42689
# AtShot_loc_y_off_player_1    42689
# AtRim_loc_x_off_player_1     57537
# AtRim_loc_y_off_player_1     57537
# AtShot_loc_x_off_player_2    42688
# AtShot_loc_y_off_player_2    42688
# AtRim_loc_x_off_player_2     57536
# AtRim_loc_y_off_player_2     57536
# AtShot_loc_x_off_player_3    42689
# AtShot_loc_y_off_player_3    42689
# AtRim_loc_x_off_player_3     57537
# AtRim_loc_y_off_player_3     57537
# AtShot_loc_x_off_player_4    42689
# AtShot_loc_y_off_player_4    42689
# AtRim_loc_x_off_player_4     57537
# AtRim_loc_y_off_player_4     57537
# AtShot_loc_x_off_player_5    42714
# AtShot_loc_y_off_player_5    42714
# AtRim_loc_x_off_player_5     57557
# AtRim_loc_y_off_player_5     57557
# AtShot_loc_x_def_player_1    42689
# AtShot_loc_y_def_player_1    42689
# AtRim_loc_x_def_player_1     57537
# AtRim_loc_y_def_player_1     57537
# AtShot_loc_x_def_player_2    42688
# AtShot_loc_y_def_player_2    42688
# AtRim_loc_x_def_player_2     57536
# AtRim_loc_y_def_player_2     57536
# AtShot_loc_x_def_player_3    42689
# AtShot_loc_y_def_player_3    42689
# AtRim_loc_x_def_player_3     57536
# AtRim_loc_y_def_player_3     57536
# AtShot_loc_x_def_player_4    42686
# AtShot_loc_y_def_player_4    42686
# AtRim_loc_x_def_player_4     57534
# AtRim_loc_y_def_player_4     57534
# AtShot_loc_x_def_player_5    42720
# AtShot_loc_y_def_player_5    42720
# AtRim_loc_x_def_player_5     57565
# AtRim_loc_y_def_player_5     57565
# dtype: int64

# %%
pbp_test = pd.read_csv("testing_data_pbp.csv")
pbp_test.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
pbp_test.set_index("Id", inplace = True)
pbp_test.head()
# Out:
#     game_id  playbyplayorder_id  row_type  off_team_id  def_team_id  \
# Id
# 1      5838             1148157      shot            1            3
# 2      4902              964867  final ft            8            3
# 3      6918             1359847      shot           11            3
# 4      1429              281709      shot           28            3
# 5      6007             1181434      shot            7            3
#
#     home_team_id  away_team_id  ftmade  ftmissed  fg2made  ...  \
# Id                                                         ...
# 1              1             3       0         0        1  ...
# 2              8             3       0         1        0  ...
# 3             11             3       0         0        0  ...
# 4              3            28       0         0        1  ...
# 5              3             7       0         0        0  ...
#
#     playerid_off_player_1  playerid_off_player_2  playerid_off_player_3  \
# Id
# 1                       4                    162                    196
# 2                     355                     61                     15
# 3                      81                    186                    311
# 4                     103                    108                    112
# 5                      49                    153                    298
#
#     playerid_off_player_4  playerid_off_player_5  playerid_def_player_1  \
# Id
# 1                     260                    192                     18
# 2                     137                    410                    376
# 3                     228                    854                    357
# 4                     290                    378                    357
# 5                     878                    475                     18
#
#     playerid_def_player_2  playerid_def_player_3 playerid_def_player_4  \
# Id
# 1                      92                    212                   874
# 2                     135                    928                   818
# 3                      55                     20                   204
# 4                      55                     20                   204
# 5                     214                     23                   874
#
#    playerid_def_player_5
# Id
# 1                    166
# 2                    166
# 3                    166
# 4                    166
# 5                    166
#
# [5 rows x 31 columns]

# %%
pbp_test.shape
# Out:
# (390550, 31)

# %%
pbp_test.isnull().sum()
# Out:
# game_id                  0
# playbyplayorder_id       0
# row_type                 0
# off_team_id              0
# def_team_id              0
# home_team_id             0
# away_team_id             0
# ftmade                   0
# ftmissed                 0
# fg2made                  0
# fg2missed                0
# fg2attempted             0
# fg3made                  0
# fg3missed                0
# fg3attempted             0
# secondchance             0
# andone                   0
# inbonus                  0
# eventdescription         0
# actiondescription        0
# shooter_player_id        0
# playerid_off_player_1    0
# playerid_off_player_2    0
# playerid_off_player_3    0
# playerid_off_player_4    0
# playerid_off_player_5    0
# playerid_def_player_1    0
# playerid_def_player_2    0
# playerid_def_player_3    0
# playerid_def_player_4    0
# playerid_def_player_5    0
# dtype: int64

# %%
loc_train = pd.read_csv("training_data_loc.csv")
loc_train.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
loc_train.set_index("Id", inplace = True)
loc_train.head()
# Out:
#     game_id  playbyplayorder_id row_type  AtShot_loc_x_off_player_1  \
# Id
# 1         8                1379     shot                 -43.648817
# 2         8                1380     shot                 -41.179048
# 3         8                1381     shot                 -44.880723
# 4         8                1382     shot                 -36.324736
# 5         8                1383     shot                 -27.609036
#
#     AtShot_loc_y_off_player_1  AtRim_loc_x_off_player_1  \
# Id
# 1                  -21.886196                -42.289158
# 2                  -23.891722                -37.122629
# 3                  -23.307184                -44.240890
# 4                   23.242563                -30.859169
# 5                   -6.286383                -19.092240
#
#     AtRim_loc_y_off_player_1  AtShot_loc_x_off_player_2  \
# Id
# 1                 -22.517425                 -39.060457
# 2                 -23.177840                 -40.540140
# 3                 -21.381771                 -43.861148
# 4                  18.254055                 -41.560159
# 5                  -7.244735                 -19.579963
#
#     AtShot_loc_y_off_player_2  AtRim_loc_x_off_player_2  ...  \
# Id                                                       ...
# 1                   -6.256763                -37.986458  ...
# 2                   22.875044                -38.674739  ...
# 3                    2.653954                -41.780069  ...
# 4                  -15.662187                -42.533999  ...
# 5                  -15.127800                -11.755558  ...
#
#     AtRim_loc_x_def_player_3  AtRim_loc_y_def_player_3  \
# Id
# 1                 -37.699404                 -5.352922
# 2                 -39.016553                  3.298064
# 3                 -42.475850                  3.011978
# 4                 -38.344859                 -3.909418
# 5                 -33.070691                 -8.653539
#
#     AtShot_loc_x_def_player_4  AtShot_loc_y_def_player_4  \
# Id
# 1                  -37.297139                   0.203133
# 2                  -39.567045                  -2.037872
# 3                  -41.932962                  -7.616737
# 4                  -40.504097                  13.970456
# 5                  -41.034914                   3.981984
#
#     AtRim_loc_x_def_player_4  AtRim_loc_y_def_player_4  \
# Id
# 1                 -36.933941                 -0.336016
# 2                 -39.988985                 -0.909305
# 3                 -41.760967                 -4.860211
# 4                 -37.996230                  9.926756
# 5                 -39.006937                  4.605167
#
#     AtShot_loc_x_def_player_5  AtShot_loc_y_def_player_5  \
# Id
# 1                  -42.696037                  -9.402359
# 2                  -40.790796                  14.652964
# 3                  -28.924595                  -7.303918
# 4                  -34.313047                 -17.530376
# 5                  -36.231217                  -2.679454
#
#     AtRim_loc_x_def_player_5  AtRim_loc_y_def_player_5
# Id
# 1                 -41.918629                 -8.539802
# 2                 -40.390343                 13.323796
# 3                 -30.620121                 -8.088317
# 4                 -36.845039                -17.290519
# 5                 -40.551412                 -5.541517
#
# [5 rows x 43 columns]

# %%
loc_train.shape
# Out:
# (372181, 43)

# %%
loc_train.isnull().sum()
# Out:
# game_id                          0
# playbyplayorder_id               0
# row_type                         0
# AtShot_loc_x_off_player_1    39798
# AtShot_loc_y_off_player_1    39798
# AtRim_loc_x_off_player_1     54265
# AtRim_loc_y_off_player_1     54265
# AtShot_loc_x_off_player_2    39791
# AtShot_loc_y_off_player_2    39791
# AtRim_loc_x_off_player_2     54257
# AtRim_loc_y_off_player_2     54257
# AtShot_loc_x_off_player_3    39789
# AtShot_loc_y_off_player_3    39789
# AtRim_loc_x_off_player_3     54256
# AtRim_loc_y_off_player_3     54256
# AtShot_loc_x_off_player_4    39790
# AtShot_loc_y_off_player_4    39790
# AtRim_loc_x_off_player_4     54257
# AtRim_loc_y_off_player_4     54257
# AtShot_loc_x_off_player_5    39813
# AtShot_loc_y_off_player_5    39813
# AtRim_loc_x_off_player_5     54274
# AtRim_loc_y_off_player_5     54274
# AtShot_loc_x_def_player_1    39789
# AtShot_loc_y_def_player_1    39789
# AtRim_loc_x_def_player_1     54256
# AtRim_loc_y_def_player_1     54256
# AtShot_loc_x_def_player_2    39792
# AtShot_loc_y_def_player_2    39792
# AtRim_loc_x_def_player_2     54258
# AtRim_loc_y_def_player_2     54258
# AtShot_loc_x_def_player_3    39789
# AtShot_loc_y_def_player_3    39789
# AtRim_loc_x_def_player_3     54256
# AtRim_loc_y_def_player_3     54256
# AtShot_loc_x_def_player_4    39791
# AtShot_loc_y_def_player_4    39791
# AtRim_loc_x_def_player_4     54258
# AtRim_loc_y_def_player_4     54258
# AtShot_loc_x_def_player_5    39817
# AtShot_loc_y_def_player_5    39817
# AtRim_loc_x_def_player_5     54277
# AtRim_loc_y_def_player_5     54277
# dtype: int64

# %%
pbp_train = pd.read_csv("training_data_pbp.csv")
pbp_train.rename(columns = {'Unnamed: 0':'Id'}, inplace = True)
pbp_train.set_index("Id", inplace = True)
pbp_train.head()
# Out:
#     game_id  playbyplayorder_id row_type f.oreb  reboffensive  rebdefensive  \
# Id
# 1      3380              665919     shot     No             0             1
# 2      2316              456069     shot    NaN             0             0
# 3      6244             1227471     shot    Yes             1             0
# 4      5349             1052145     shot     No             0             1
# 5      7411             1455880     shot     No             0             1
#
#     off_team_id  def_team_id  home_team_id  away_team_id  ...  \
# Id                                                        ...
# 1            25            3            25             3  ...
# 2            12            3             3            12  ...
# 3            28            3             3            28  ...
# 4             6            3             6             3  ...
# 5            13            3             3            13  ...
#
#     playerid_off_player_1  playerid_off_player_2  playerid_off_player_3  \
# Id
# 1                      59                    194                    624
# 2                      87                    124                    283
# 3                     103                    108                    161
# 4                      41                    180                    372
# 5                      91                    165                     93
#
#     playerid_off_player_4  playerid_off_player_5  playerid_def_player_1  \
# Id
# 1                     418                    326                    357
# 2                     916                    487                     20
# 3                     112                    290                     22
# 4                     964                    374                     18
# 5                     229                    367                     18
#
#     playerid_def_player_2  playerid_def_player_3  playerid_def_player_4  \
# Id
# 1                      55                     20                    204
# 2                     204                    376                    818
# 3                      92                    212                    269
# 4                      22                     92                    212
# 5                      22                    212                    874
#
#     playerid_def_player_5
# Id
# 1                     166
# 2                     166
# 3                     166
# 4                     166
# 5                     166
#
# [5 rows x 35 columns]

# %%
pbp_train.shape
# Out:
# (372181, 35)

# %%
pbp_train.isnull().sum()
# Out:
# game_id                       0
# playbyplayorder_id            0
# row_type                      0
# f.oreb                   187834
# reboffensive                  0
# rebdefensive                  0
# off_team_id                   0
# def_team_id                   0
# home_team_id                  0
# away_team_id                  0
# ftmade                        0
# ftmissed                      0
# fg2made                       0
# fg2missed                     0
# fg2attempted                  0
# fg3made                       0
# fg3missed                     0
# fg3attempted                  0
# secondchance                  0
# andone                        0
# inbonus                       0
# eventdescription              0
# actiondescription             0
# shooter_player_id             0
# reb_player_id            205556
# playerid_off_player_1         0
# playerid_off_player_2         0
# playerid_off_player_3         0
# playerid_off_player_4         0
# playerid_off_player_5         0
# playerid_def_player_1         0
# playerid_def_player_2         0
# playerid_def_player_3         0
# playerid_def_player_4         0
# playerid_def_player_5         0
# dtype: int64
